# %%
import os, sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../src")))

from dfutility_helper.utils import add_map

# %%
params = dbutils.widgets.getAll()
catalog = params.pop('catalog')

# %%
raw_df = spark.read \
    .format("csv") \
    .option("header", "true") \
        .option("mode", "permissive") \
            .option("delimiter", ",") \
                .load(
                    path=f"/Volumes/{catalog}/00-landing/source_citibike_data",
                    pathGlobFilter="*.csv"
                )

# %%
raw_df = add_map(raw_df, **params)

# %%
raw_df.write \
    .format("delta") \
        .mode("overwrite") \
            .saveAsTable(f"{catalog}.`01-bronze`.jc_city")
